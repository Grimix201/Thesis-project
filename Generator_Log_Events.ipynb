# %%
from pandas import DataFrame, read_csv, concat

sending_log = read_csv("event_log_choice_1_1000.csv", sep=';')
# print(sending_log)
select_log = sending_log[:20]
print(select_log)

print("FOREACH\n")
for index, row in select_log.iterrows():
    print(index, row['case'], row['activity'], row['time'])
    s = f"{index} {row[0]} {row[1]} {row[2]}"
    print(s)

#createSocketClient()
# Out:
#     case activity                 time
# 0      1      a_1  2015-01-05 00:02:05
# 1      1      c_1  2015-01-05 00:02:05
# 2      1      d_1  2015-01-05 00:02:11
# 3      2      a_1  2015-01-05 00:02:19
# 4      2      d_1  2015-01-05 00:02:21
# 5      1      f_1  2015-01-05 00:02:27
# 6      5      b_1  2015-01-05 00:06:26
# 7      2      c_1  2015-01-05 00:06:48
# 8      2      f_1  2015-01-05 00:06:53
# 9      4      a_1  2015-01-05 00:07:05
# 10     5      d_1  2015-01-05 00:07:16
# 11     6      a_1  2015-01-05 00:07:22
# 12     5      e_1  2015-01-05 00:07:41
# 13     6      c_1  2015-01-05 00:07:45
# 14     4      d_1  2015-01-05 00:08:00
# 15     5      g_1  2015-01-05 00:08:10
# 16     7      b_1  2015-01-05 00:08:57
# 17     8      b_1  2015-01-05 00:09:10
# 18     8      d_1  2015-01-05 00:09:11
# 19     4      c_1  2015-01-05 00:09:15
# FOREACH
#
# 0 1 a_1 2015-01-05 00:02:05
# 0 1 a_1 2015-01-05 00:02:05
# 1 1 c_1 2015-01-05 00:02:05
# 1 1 c_1 2015-01-05 00:02:05
# ...
